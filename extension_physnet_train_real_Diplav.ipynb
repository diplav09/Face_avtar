# %%
from google.colab import drive
import os
drive.mount('/content/gdrive', force_remount=True)
os.environ['SIR_CONFIG_DIR'] = "/content/gdrive/"
# Change to your local path if needed

# path = '/content/gdrive/My Drive/Biofacenet_n/DECA'
# os.chdir(path)
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/DECA'
os.chdir(path)

# %%
# !nvidia-smi
# Out:
# Wed Mar 23 18:02:42 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
ls /content/
# Out:
# gdrive/  sample_data/

# %%
pwd
# Out:
# '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/DECA'

# %% [markdown]
# # Copy Data

# %%
path = '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/FaceForensics/videos/original_sequences/youtube/raw/'
os.chdir(path)

# %%
import patoolib
from glob import glob

# %%
testpath = '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/FaceForensics/videos/original_sequences/youtube/raw/bupt_video_31march/'
files = glob(testpath + '/*.h5')

# %%
# !zip -r ./bupt_video_31march.zip ./bupt_video_31march
archive_path = '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/FaceForensics/videos/original_sequences/youtube/raw/bupt_video_31march.zip'
# testpath = '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/FaceForensics/videos/original_sequences/youtube/raw/bupt_video_31march/' 
patoolib.create_archive(archive_path, files, interactive=False)
# Out:
# patool: Creating /content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/FaceForensics/videos/original_sequences/youtube/raw/bupt_video_31march.zip ...
# ...

# %%
# !zip -r /content/bupt_balanced_480_09_11_no_mask_3_19.zip ./bupt_balanced_480_09_11_no_mask_3_19
# !cp ./bupt_balanced_480_09_11_no_mask_3_19.zip /content/bupt_balanced_480_09_11_no_mask_3_19.zip
# !unzip ./bupt_balanced_480_09_11_no_mask_3_19.zip -d /content

# !zip -r ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21
# !cp ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip
# !unzip ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip -d /content
# Out:
#   adding: bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/ (stored 0%)
#   adding: bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/Africanm015pr162-FaceId-0_align_bidmc_01_syn.h5 (deflated 52%)
#   adding: bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/Africanm015z4j62-FaceId-0_align_bidmc_02_syn.h5 (deflated 61%)
#   adding: bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/Africanm01kbx27-FaceId-1_align_bidmc_03_syn.h5 (deflated 59%)
#   adding: bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/Africanm01l8wwt2-FaceId-0_align_bidmc_04_syn.h5 (deflated 53%)
#   adding: bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/Africanm01m4rnj102-FaceId-0_align_bidmc_05_syn.h5
# zip I/O error: Transport endpoint is not connected
# zip error: Output file write failure (write error on zip file)
# ...

# %%
# !zip -r ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21
# !cp ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip

# !p7zip ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive:
# 1 file, 909339635 bytes (868 MiB)
#
# Creating archive: ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip.7z
#
# Items to compress: 1
#
#  99% 1 + bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.zip
# Files read from disk: 1
# Archive size: 899537424 bytes (858 MiB)
#   0M Removing ./bupt_balanced_480_09_11_no_m . _multiplication_09_11_3_21.zip
# Everything is Ok
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive:
# 1 folder, 476 files, 49141310848 bytes (46 GiB)
#
# Creating archive: ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z
# ...

# %%
# !cp ./bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z

# %%
# !pip install patool
# Out:
# ...
#      |████████████████████████████████| 77 kB 3.7 MB/s
# ...

# %%
# !p7zip -d /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z -o /content/
import patoolib
patoolib.extract_archive('/content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z',outdir='/content/')
# Out:
# patool: Extracting /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z ...
# patool: running /usr/bin/7z x -o/content/ -- /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z
# patool: ... /content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z extracted to `/content/'.
# '/content/'

# %%
dir_test = './bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21'#'./bupt_balanced_480_09_11_no_mask_3_19' # './bupt_balanced_480_11_09_no_mask_10_12'
list_dir = os.listdir(dir_test)
print(len(list_dir))
# print(list_dir[238:358])
# # print(list_dir[:120])
# Out:
# 476

# %%
pwd
# Out:
# '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n/DECA'

# %% [markdown]
# # Library

# %%
import os, os.path

import torch
tr = torch
import torch.nn as nn
from torch.nn import init
import torchvision as tv
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn.functional as F
import torch.nn.utils.spectral_norm as spectral_norm

import re
import numpy as np
import cv2
import random
from PIL import Image 

from scipy.io import loadmat
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from numpy import linalg as LA

from torch.utils.data import DataLoader
import json
import h5py

from torchvision.transforms import RandomRotation, ToPILImage, ToTensor, ColorJitter
import torchvision.transforms.functional as TF
from sklearn.model_selection import train_test_split


import sys
import argparse
from tqdm import tqdm
from types import SimpleNamespace
import glob

# !pip install mtcnn
# from mtcnn import MTCNN
# detector = MTCNN()

# Fix random seed for reproducability
rseed = 42
np.random.seed(rseed)
torch.backends.cudnn.deterministic = True
torch.manual_seed(rseed)
if torch.cuda.is_available():
  torch.cuda.manual_seed_all(rseed)

# %% [markdown]
# # Helper

# %%
def img_show(img):
  plt.figure(figsize=(5, 5))
  plt.imshow(img)
  plt.show()

def tensor2img(tensor, normalization=False):
  img = tensor.cpu().numpy().transpose((1, 2, 0))
  if normalization: # Normalize to [0, 1] for visualization 
   img = (img - img.min()) / (img.max() - img.min())
  else: # Convert [-1, 1] to [0, 1]
   img = (img + 1) / 2
  return img

def tensor_show(tensor):
  img = tensor2img(tensor)
  plt.figure(figsize=(5, 5))
  plt.imshow(img)
  plt.show()

def readSigfile(filename):
  """ Load signal from file.
      Return a BVPsignal/ECGsignal object.
  """
  """ Load BVP signal.
      Must return a 1-dim (row array) signal
  """
  gtTrace = []
  gtTime = []
  gtHR = []
  with open(filename, 'r') as f:
      x = f.readlines()
  
  s = x[0].split(' ')
  s = list(filter(lambda a: a != '', s))
  gtTrace = np.array(s).astype(np.float64)

  t = x[2].split(' ')
  t = list(filter(lambda a: a != '', t))
  gtTime = np.array(t).astype(np.float64)
  
  hr = x[1].split(' ')
  hr = list(filter(lambda a: a != '', hr))
  gtHR = np.array(hr).astype(np.float64)

  data = np.array(gtTrace)
  time = np.array(gtTime)
  SIG_SampleRate = np.round(1/np.mean(np.diff(time)))
  # print(SIG_SampleRate)

  return SIG_SampleRate, gtHR

# %% [markdown]
# # Dataloader

# %%
import pandas as pd
class DatasetUBFC(Dataset):
  """
      Dataset class for training network.
  """
  def __init__(
      self, root_dir, session_names, num_samples, 
      seq_length, resize_shape, val=False, transform=False):
    """
    :param path: Path to hdf5 file
    :param labels: tuple of label names to use (e.g.: ('pulseNumerical', 'resp_signal') or ('pulse_signal', ) )
        Note that the first label must be the pulse rate if it is present!
    """

    # self.hr_path = hr_path
    self.resize_shape = resize_shape
    self.transform = transform
    self.sessions = session_names
    self.seq_length = seq_length    

    self.all_sessions = []
    self.length = num_samples
    self.ppg_der = {}
    self.frames = {}
    self.avg_img = {}
    self.hr = {}
    # self.color_transform = ColorJitter(brightness=(0.7, 1.3),
    #                                   contrast=(0.8, 1.2),
    #                                   saturation=(0.8, 1.2),
    #                                   hue=(0, 0))
    
    print(len(self.sessions),self.sessions) 
    self.files = os.listdir(root_dir[1])#[238:358]
    print(len(self.files))
    i = -1
    # if val:
    #   len_session = 1 # only real data
    # else:
    #   len_session = len(self.sessions)
    # len_session = len(self.sessions)
    len_session = 2

    
    for num_dataset in range(1, len_session):
      print(num_dataset)
      print(len(self.sessions[num_dataset]))
      for session_num, session in enumerate(self.sessions[num_dataset]):
        try:
          if num_dataset == 0:
        
            db = h5py.File(os.path.join(root_dir[num_dataset], session + '.h5'), 'r')
          else:
            print(self.files[session])
            db = h5py.File(os.path.join(root_dir[num_dataset], self.files[session]), 'r')
          i += 1
          frames = db['dataset_1']
          target = db['ppg']

          # hr_file = pd.read_csv(os.path.join(self.hr_path, session + '/hr.csv'), header=None)
          # self.hr[session] = hr_file[0].values
          
          # Normalize PPG
          target = target - np.mean(target)
          target = target / np.std(target) #target = target / np.max(np.abs(target))

          # Avg Image
          # avg_img = np.mean(frames, 0)
          # avg_img = cv2.resize(
          #   avg_img, self.resize_shape, 
          #   interpolation=cv2.INTER_LINEAR
          #   )
          # avg_img = torch.from_numpy(avg_img).permute(2, 0, 1).float()

          self.frames[i] = frames
          self.ppg_der[i] = target
          # self.avg_img[session] = avg_img
        except:
          print('error')

    print('frames.shape', len(self.frames))
  def __len__(self):
    return (self.length)

  def __getitem__(self, idx):

    # Pick a session
    session_num = np.random.randint(low=0, high=len(self.frames))

    frames = self.frames[session_num]
    cur_ppg_signal = self.ppg_der[session_num]
    # avg_img = self.avg_img[subject].clone()
    
    # Pick a random frame
    cur_frame_num = np.random.randint(
        low=0, high=len(frames) - self.seq_length # Can't pick the last frame.
        )

    # Hr
    # hr = self.hr[subject][cur_frame_num : cur_frame_num+self.seq_length]
    
    # Avg image
    # avg_img = avg_img / 127.5 - 1

    # Flip
    if self.transform:
      k = random.randint(0, 1)
      k_h = random.randint(0, 1)

    # Following frames
    temp_next_frames_list = []
    temp_next_ppgs_list = []
    
    for j in range(self.seq_length):
      next_frame = frames[cur_frame_num + j]
      next_frame = cv2.resize(
          next_frame, self.resize_shape, 
          interpolation=cv2.INTER_LINEAR
          )
      next_frame = torch.from_numpy(next_frame).permute(2, 0, 1).float()
      next_frame = next_frame / 127.5 - 1
      
      # Augmentation
      if (self.transform == True) and (k == 1):
        next_frame = torch.flip(next_frame, [2])
      if (self.transform == True) and (k_h == 1):
        next_frame = torch.flip(next_frame, [1])

      # PPG
      next_ppg_value = cur_ppg_signal[cur_frame_num + j]

      temp_next_frames_list.append(next_frame)
      temp_next_ppgs_list.append(
          torch.tensor(next_ppg_value).float()
          )
    
    # Return
    data = {
      'next_frame': torch.stack(temp_next_frames_list),
      # 'hr': np.mean(hr),
      'next_ppg_value': torch.stack(temp_next_ppgs_list),
      # 'avg_img': avg_img,
    }

    return data

# %%
# # Test Dataloader
# val_session_nums = [8, 1, 37, 3]

# val_session_names = []
# for cur_session_num in val_session_nums:
#   cur_session_name = 'subject' + str(cur_session_num) 
#   val_session_names.append(cur_session_name)

# root_dir = '/content/Colorless Camera/abd-skin-segmentation-master/UBFC_cropped'
# hr_path = '/content/gdrive/My Drive/0_Recent_Projects/Colorless Camera/datasets/UBFC/DATASET_2'

# params = {
#     'num_samples': 8,
#     'seq_length': 256,
#     'batch_size': 4,
#     'img_shape': (80, 80),
# }

# val_set = DatasetUBFC(
#     root_dir=root_dir, 
#     hr_path=hr_path,
#     session_names=val_session_names, 
#     num_samples=params['num_samples'],
#     seq_length=params['seq_length'], 
#     resize_shape=params['img_shape'],
#     )

# ppg_val_loader = DataLoader(
#     val_set,
#     batch_size=params['batch_size'],
#     shuffle=False,
#     num_workers=0,
#     pin_memory=True
#     )

# for data in ppg_val_loader:
#   next_frames = data['next_frame']
#   next_ppg_value = data['next_ppg_value']

#   print(next_frames.shape)
#   print(next_ppg_value.shape)

#   print(next_frames.dtype)
#   print(next_ppg_value.dtype)

#   tensor_show(next_frames[0, 0])

# %% [markdown]
# # Loss

# %%
class Neg_Pearson(nn.Module):    # Pearson range [-1, 1] so if < 0, abs|loss| ; if >0, 1- loss
  def __init__(self):
    super(Neg_Pearson,self).__init__()
    return
      
  def forward(self, preds, labels):       # all variable operation
    loss = torch.tensor(0).float().to(preds.device)
    # preds = (preds - torch.mean(preds)) / torch.std(preds)
    # labels = (labels - torch.mean(labels)) / torch.std(labels)
    for i in range(preds.shape[0]):
      preds_nor = (preds[i] - torch.mean(preds[i])) / (torch.std(preds[i]))
      labels_nor = (labels[i] - torch.mean(labels[i])) / (torch.std(labels[i]))

      # if labels_nor == 0:
      #   print('wrong')
      # if torch.sum(preds_nor)==0 or torch.sum(labels_nor)==0:
      #     continue

      if torch.sum(torch.isnan(preds_nor)) or torch.sum(torch.isnan(labels_nor)):
          continue

      #sum_x = torch.sum((preds[i] - torch.mean(preds[i])) / torch.std(preds[i]))               # x
      #sum_y = torch.sum((labels[i] - torch.mean(labels[i])) / torch.std(labels[i]))               # y
      sum_x = torch.sum(preds_nor)                # x
      sum_y = torch.sum(labels_nor)               # y
      sum_xy = torch.sum(preds_nor * labels_nor)        # xy
      sum_x2 = torch.sum(torch.pow(preds_nor, 2))  # x^2
      sum_y2 = torch.sum(torch.pow(labels_nor, 2)) # y^2
      N = preds.shape[1]
      pearson = (N*sum_xy - sum_x*sum_y)/(torch.sqrt((N*sum_x2 - torch.pow(sum_x,2))*(N*sum_y2 - torch.pow(sum_y,2)))+1e-7)
      # print(pearson, sum_xy, sum_x2, sum_y2)
      # print(labels[i])


      # if (pearson>=0).data.cpu().numpy():    # torch.cuda.ByteTensor -->  numpy
      #    loss += 1 - pearson
      # else:
      #    loss += 1 - torch.abs(pearson)
      
      loss += 1 - pearson
        
    loss = loss/preds.shape[0]
    return loss

class Neg_Pearson_focal(nn.Module):    # Pearson range [-1, 1] so if < 0, abs|loss| ; if >0, 1- loss
  def __init__(self):
    super(Neg_Pearson_focal,self).__init__()
    return
      
  def forward(self, preds, labels, gamma=2):       # all variable operation
    loss = 0
    # preds = (preds - torch.mean(preds)) / torch.std(preds)
    # labels = (labels - torch.mean(labels)) / torch.std(labels)
    for i in range(preds.shape[0]):
      preds_nor = (preds[i] - torch.mean(preds[i])) / torch.std(preds[i])
      labels_nor = (labels[i] - torch.mean(labels[i])) / torch.std(labels[i])


      # if torch.sum(preds_nor)==0 or torch.sum(labels_nor)==0:
      #     continue

      if torch.sum(torch.isnan(preds_nor)) or torch.sum(torch.isnan(labels_nor)):
          continue
      #sum_x = torch.sum((preds[i] - torch.mean(preds[i])) / torch.std(preds[i]))               # x
      #sum_y = torch.sum((labels[i] - torch.mean(labels[i])) / torch.std(labels[i]))               # y
      sum_x = torch.sum(preds_nor)                # x
      sum_y = torch.sum(labels_nor)               # y
      sum_xy = torch.sum(preds_nor * labels_nor)        # xy
      sum_x2 = torch.sum(torch.pow(preds_nor, 2))  # x^2
      sum_y2 = torch.sum(torch.pow(labels_nor, 2)) # y^2
      N = preds.shape[1]
      pearson = (N*sum_xy - sum_x*sum_y)/(torch.sqrt((N*sum_x2 - torch.pow(sum_x,2))*(N*sum_y2 - torch.pow(sum_y,2))))

      #if (pearson>=0).data.cpu().numpy():    # torch.cuda.ByteTensor -->  numpy
      #    loss += 1 - pearson
      #else:
      #    loss += 1 - torch.abs(pearson)
      # print('pearson', pearson)
      loss_orig = 1 - pearson 
      weight = (loss_orig / 2) ** gamma

      loss += loss_orig * weight
      # print('loss', loss)

    loss = loss/preds.shape[0]
    return loss

class SNRLoss(nn.Module):
  def __init__(self):
    super(SNRLoss, self).__init__()

  def forward(self, outputs: tr.Tensor, targets: tr.Tensor, Fs=30):
    device = outputs.device
    if not outputs.is_cuda:
      torch.backends.mkl.is_available()

    N = outputs.shape[-1]
    #print(N)
    pulse_band = tr.tensor([45/60., 150/60.], dtype=tr.float32).to(device)
    f = tr.linspace(0, Fs/2, int(N/2)+1, dtype=tr.float32).to(device)
    #print('f', f)
    min_idx = tr.argmin(tr.abs(f - pulse_band[0]))
    max_idx = tr.argmin(tr.abs(f - pulse_band[1]))

    outputs = outputs.view(-1, N)
    targets = targets.view(-1, 1)
    #print(outputs.shape)
    X = torch.fft.rfft(outputs, dim=1, norm='forward')
    #print(X.shape)
    #P1 = tr.add(X[:, :, 0]**2, X[:, :, 1]**2)                                   # One sided Power spectral density
    P1 = tr.abs(X) ** 2
    # calculate indices corresponding to refs
    ref_idxs = []
    for ref in targets:
      ref_idxs.append(tr.argmin(tr.abs(f-ref)))

    # calc SNR for each batch
    losses = tr.empty((len(ref_idxs),), dtype=tr.float32)
    freq_num_in_pulse_range = max_idx-min_idx
    for count, ref_idx in enumerate(ref_idxs):
      pulse_freq_amp = P1[count, ref_idx]
      other_avrg = (tr.sum(P1[count, min_idx:ref_idx-1]) + tr.sum(P1[count, ref_idx+2:max_idx]))/(freq_num_in_pulse_range-3)
      losses[count] = -10*tr.log10(pulse_freq_amp/other_avrg)

    return tr.mean(losses)

# %% [markdown]
# # Network

# %%
class RPPGNet(nn.Module):
  def __init__(self, seq_length):
    super().__init__()

    self.layers = nn.Sequential(
        nn.Conv3d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(16),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(16),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(32),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(64),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(128),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=(0, 1, 1)),
        nn.Conv3d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(256),
        nn.ReLU()
    )
    
    self.pooling = nn.AdaptiveAvgPool3d((seq_length, 1, 1))
    self.final_conv = nn.Conv3d(in_channels=256, out_channels=1, kernel_size=1, stride=1, padding=0, bias=True)
    
  def forward(self, A):        
    out = self.layers(A)    
    out = self.pooling(out)
    out = self.final_conv(out)

    return out

class Sine(nn.Module):
  def __init__(self, w0 = 1.):
    super().__init__()
    self.w0 = w0
  def forward(self, x):
    return torch.sin(self.w0 * x)

class RPPGNetModified(nn.Module):
  def __init__(self, seq_length):
    super().__init__()

    self.layers = nn.Sequential(
        nn.Conv3d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True),
        nn.InstanceNorm3d(16),
        Sine(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True),
        nn.InstanceNorm3d(16),
        Sine(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True),
        nn.InstanceNorm3d(32),
        Sine(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True),
        nn.InstanceNorm3d(64),
        Sine(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True),
        nn.InstanceNorm3d(128),
        Sine(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=(0, 1, 1)),
        nn.Conv3d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True),
        nn.InstanceNorm3d(256),
        Sine()
    )
    
    self.pooling = nn.AdaptiveAvgPool3d((seq_length, 1, 1))
    self.final_conv = nn.Conv3d(in_channels=256, out_channels=1, kernel_size=1, stride=1, padding=0, bias=True)
    
  def forward(self, A):        
    out = self.layers(A)    
    out = self.pooling(out)
    out = self.final_conv(out)

    return out

class PhysNet(nn.Module):
  def __init__(self, frames=128):  
    super(PhysNet, self).__init__()
    
    self.ConvBlock1 = nn.Sequential(
        nn.Conv3d(3, 16, [1,5,5],stride=1, padding=[0,2,2]),
        nn.BatchNorm3d(16),
        nn.ReLU(inplace=True),
    )

    self.ConvBlock2 = nn.Sequential(
        nn.Conv3d(16, 32, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(32),
        nn.ReLU(inplace=True),
    )
    self.ConvBlock3 = nn.Sequential(
        nn.Conv3d(32, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    
    self.ConvBlock4 = nn.Sequential(
        nn.Conv3d(64, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    self.ConvBlock5 = nn.Sequential(
        nn.Conv3d(64, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    self.ConvBlock6 = nn.Sequential(
        nn.Conv3d(64, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    self.ConvBlock7 = nn.Sequential(
        nn.Conv3d(64, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    self.ConvBlock8 = nn.Sequential(
        nn.Conv3d(64, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    self.ConvBlock9 = nn.Sequential(
        nn.Conv3d(64, 64, [3, 3, 3], stride=1, padding=1),
        nn.BatchNorm3d(64),
        nn.ReLU(inplace=True),
    )
    
    self.upsample = nn.Sequential(
        nn.ConvTranspose3d(in_channels=64, out_channels=64, kernel_size=[4,1,1], stride=[2,1,1], padding=[1,0,0]),   #[1, 128, 32]
        nn.BatchNorm3d(64),
        nn.ELU(),
    )
    self.upsample2 = nn.Sequential(
        nn.ConvTranspose3d(in_channels=64, out_channels=64, kernel_size=[4,1,1], stride=[2,1,1], padding=[1,0,0]),   #[1, 128, 32]
        nn.BatchNorm3d(64),
        nn.ELU(),
    )

    self.ConvBlock10 = nn.Conv3d(64, 1, [1,1,1],stride=1, padding=0)
    
    self.MaxpoolSpa = nn.MaxPool3d((1, 2, 2), stride=(1, 2, 2))
    self.MaxpoolSpaTem = nn.MaxPool3d((2, 2, 2), stride=2)
    
    
    #self.poolspa = nn.AdaptiveMaxPool3d((frames,1,1))    # pool only spatial space 
    self.poolspa = nn.AdaptiveAvgPool3d((frames,1,1))
      
  def forward(self, x):	    	# x [3, T, 128,128]
    x_visual = x
    [batch,channel,length,width,height] = x.shape
      
    x = self.ConvBlock1(x)		     # x [3, T, 128,128]
    x = self.MaxpoolSpa(x)       # x [16, T, 64,64]
    
    x = self.ConvBlock2(x)		    # x [32, T, 64,64]
    x_visual6464 = self.ConvBlock3(x)	    	# x [32, T, 64,64]
    x = self.MaxpoolSpaTem(x_visual6464)      # x [32, T/2, 32,32]    Temporal halve
    
    x = self.ConvBlock4(x)		    # x [64, T/2, 32,32]
    x_visual3232 = self.ConvBlock5(x)	    	# x [64, T/2, 32,32]
    x = self.MaxpoolSpaTem(x_visual3232)      # x [64, T/4, 16,16]
    

    x = self.ConvBlock6(x)		    # x [64, T/4, 16,16]
    x_visual1616 = self.ConvBlock7(x)	    	# x [64, T/4, 16,16]
    x = self.MaxpoolSpa(x_visual1616)      # x [64, T/4, 8,8]

    x = self.ConvBlock8(x)		    # x [64, T/4, 8, 8]
    x = self.ConvBlock9(x)		    # x [64, T/4, 8, 8]
    x = self.upsample(x)		    # x [64, T/2, 8, 8]
    x = self.upsample2(x)		    # x [64, T, 8, 8]
    
    x = self.poolspa(x)     # x [64, T, 1,1]    -->  groundtruth left and right - 7 
    x = self.ConvBlock10(x)    # x [1, T, 1,1]
    
    rPPG = x.view(-1,length)            
    
    return rPPG #, x_visual, x_visual3232, x_visual1616

class RPPGNetResnet(nn.Module):
  def __init__(self, seq_length):
    super().__init__()

    self.learned_shortcut1 = nn.Conv3d(3, 16, kernel_size=1, bias=False)
    self.layers1 = nn.Sequential(
        nn.Conv3d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(16),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(16),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0)
    )
    self.pool1 = nn.AvgPool3d(kernel_size=(1, 4, 4), stride=(1, 4, 4), padding=0)

    self.learned_shortcut2 = nn.Conv3d(16, 64, kernel_size=1, bias=False)
    self.layers2 = nn.Sequential(
        nn.Conv3d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(32),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0),
        nn.Conv3d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(64),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0)
    )
    self.pool2 = nn.AvgPool3d(kernel_size=(1, 4, 4), stride=(1, 4, 4), padding=0)

    self.learned_shortcut3 = nn.Conv3d(64, 256, kernel_size=1, bias=False)
    self.layers3 = nn.Sequential(
        nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(128),
        nn.ReLU(),
        nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=(0, 1, 1)),
        nn.Conv3d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True),
        nn.BatchNorm3d(256),
        nn.ReLU()
    )
    
    self.pool3 = nn.AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=(0, 1, 1))

    self.pooling = nn.AdaptiveAvgPool3d((seq_length, 1, 1))
    self.final_conv = nn.Conv3d(in_channels=256, out_channels=1, kernel_size=1, stride=1, padding=0, bias=True)
    
  def forward(self, A):   

    identity = A
    out = self.layers1(A)   
    out += self.learned_shortcut1(self.pool1(identity))
  
    identity = out 
    out = self.layers2(out)
    out += self.learned_shortcut2(self.pool2(identity))
    
    identity = out
    out = self.layers3(out)
    out += self.learned_shortcut3(self.pool3(identity))

    out = self.pooling(out)
    out = self.final_conv(out)

    return out

# %% [markdown]
# # Train function

# %%
def train_model(model, dataloaders, criterion, optimizer, scheduler, params):
  val_loss_history = []
  train_loss_history = []

  criterion_SNR = SNRLoss()

  min_train_loss = 9999
  min_val_loss = 9999
  min_val_loss_snr = 9999
  max_train_loss_snr = -9999

  for epoch in range(params['num_epochs']):
    print('Epoch {}/{}'.format(epoch, params['num_epochs']))
    print('-' * 10)

    # Each epoch has a training and validation phase
    phases = ['train', 'val']
    for phase in phases:
      running_loss = 0.0
      running_loss_snr = 0.0
      if phase == 'train':
        model.train()
      else:
        model.eval()  # Set model to evaluate mode

      # Iterate over data.
      for inputs in dataloaders[phase]:
        next_frames = inputs['next_frame'].to(device)
        targets = inputs['next_ppg_value'].to(device) 
        # targets_hr = inputs['hr'].to(device)  
        next_frames = torch.transpose(next_frames, 1, 2)
        # print(next_frames.shape)
       
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = model(next_frames).squeeze()
        # print(outputs.shape)
        # print(targets.shape)
        loss = criterion(outputs, targets)
        # print(loss.shape)
        if phase == 'train':
          loss.backward()
          # nn.utils.clip_grad_norm_(model.parameters(),1e3)
          optimizer.step()

        # statistics
        running_loss += loss.item()

        # if params['snr_epoch'] and epoch > params['snr_epoch']:
        #   loss_snr = criterion_SNR(outputs, targets_hr)
        #   running_loss_snr += loss_snr.item()

      epoch_loss = running_loss / len(dataloaders[phase])
      print('{} Loss: {:.4f} '.format(phase, epoch_loss))

      # if params['snr_epoch'] and epoch > params['snr_epoch']:
      #   epoch_loss_snr = running_loss_snr / len(dataloaders[phase])
      #   print('{} SNR Loss: {:.4f} '.format(phase, epoch_loss_snr))

      if phase == 'val':
        val_loss_history.append(epoch_loss)

        if epoch_loss < min_val_loss:
          print('saving in epoch', epoch)
          min_val_loss = epoch_loss
          print(f'new min loss: {min_val_loss}')
          torch.save(model.state_dict(), f"checkpoints/{params['check_point_dir']}/model_best.pt")
          
      # else:
      #   if params['snr_epoch'] and epoch > params['snr_epoch']:
      #     if epoch_loss_snr > max_train_loss_snr:
      #       print('saving in epoch according to snr', epoch)
      #       max_train_loss_snr = epoch_loss_snr
      #       print(f'new max loss_snr: {max_train_loss_snr}')
      #       torch.save(model.state_dict(), f"checkpoints/{params['check_point_dir']}/model_best_snr.pt")
        # train_loss_history.append(epoch_loss)
    
    # Scheduler
    scheduler.step()
    print('\n')      

    # Save
    torch.save(model.state_dict(), f"checkpoints/{params['check_point_dir']}/model_ep{epoch}.pt")

# %% [markdown]
# **Tain test split**

# %%
cd '/content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n'
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Kv4V2PfcDb3WIGdtBo48x6lRiYbsR3GM/Biofacenet_n

# %%
#change directory name 
fp_df = pd.read_excel('/content/gdrive/.shortcut-targets-by-id/1-up69TInc1tooCgwD7Ad1oOGMayBzkYe/R_PPG_estimation/Data Collection Entry Form V2 (Responses)-2.xlsx')
print(len(fp_df))
fp_df.info()
# Out:
# 102
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 13 columns):
#  #   Column                                                                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                102 non-null    datetime64[ns]
# ...

# %%
fp_df = fp_df.dropna(subset = ['Study ID','Fitzpatrick Skin Type'])
# fp_df = fp_df[fp_df['Fitzpatrick Skin Type'].isin([5, 6])]#keep only light skin types
print(len(fp_df))
exception_subjects  = [31, 99] #this will drop the entire subject altogether.  
fp_df = fp_df[~fp_df['Study ID'].isin(exception_subjects)]
print(len(fp_df))
fp_df = fp_df.drop(columns=list(set(fp_df) - set(['Study ID', 'Fitzpatrick Skin Type'])))
fp_df.info()
# Out:
# 102
# 102
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 101
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Study ID               102 non-null    float64
#  1   Fitzpatrick Skin Type  102 non-null    float64
# dtypes: float64(2)
# memory usage: 2.4 KB

# %%
train_subject, test_subject = train_test_split(fp_df, test_size = 0.5, random_state = rseed, stratify = fp_df['Fitzpatrick Skin Type'] )# 50% subjects in train, 50% in val + test
validation_subject, test_subject = train_test_split(test_subject, test_size = 0.8, random_state = rseed, stratify = test_subject['Fitzpatrick Skin Type'] )# 10 out of 50 in val, remaining in test
# we need to repeat above split 5 times and retrain. 
print(train_subject['Fitzpatrick Skin Type'].value_counts())
print(validation_subject['Fitzpatrick Skin Type'].value_counts())
print(test_subject['Fitzpatrick Skin Type'].value_counts())
# Out:
# 3.0    20
# 2.0    11
# 5.0     6
# 4.0     5
# 6.0     5
# 1.0     4
# Name: Fitzpatrick Skin Type, dtype: int64
# 3.0    4
# 2.0    2
# 4.0    1
# 1.0    1
# 6.0    1
# 5.0    1
# Name: Fitzpatrick Skin Type, dtype: int64
# 3.0    17
# 2.0     8
# 5.0     5
# 6.0     5
# 4.0     4
# 1.0     2
# Name: Fitzpatrick Skin Type, dtype: int64

# %%
train_subject['Study ID']
# Out:
# 68      70.0
# 8        9.0
# 42      44.0
# 92      94.0
# 35      37.0
# 75      77.0
# 54      56.0
# 12      13.0
# 32      34.0
# 91      93.0
# 0        1.0
# 31      33.0
# 51      53.0
# 61      63.0
# 63      65.0
# 44      46.0
# 65      67.0
# 26      27.0
# 73      75.0
# 80      82.0
# 57      59.0
# 64      66.0
# 21      22.0
# 2        3.0
# 88      90.0
# 94      96.0
# 66      68.0
# 74      76.0
# 38      40.0
# 56      58.0
# 23      24.0
# 52      54.0
# 53      55.0
# 27      28.0
# 72      74.0
# 47      49.0
# 16      17.0
# 95      97.0
# 29      30.0
# 101    104.0
# 34      36.0
# 3        4.0
# 46      48.0
# 76      78.0
# 69      71.0
# 5        6.0
# 25      26.0
# 48      50.0
# 20      21.0
# 39      41.0
# 79      81.0
# Name: Study ID, dtype: float64

# %%
train_videos = []
validation_videos = []
train_videos = []
test_videos = []
for subject in train_subject['Study ID']:
  for j in range(1,6):
    train_videos.append(str(int(subject)) + '_' + str(j) )
for subject in test_subject['Study ID']:
  for j in range(1,6):
    test_videos.append(str(int(subject)) + '_' +str(j) )
for subject in validation_subject['Study ID']:
  for j in range(1,6):
    validation_videos.append(str(int(subject)) + '_' +str(j) )

excepetion_videos = ['4_1','8_3', '10_5','16_5','49_5','34_1','58_5',] 
train_videos = [ tv for tv in train_videos if tv not in excepetion_videos]
validation_videos = [ tv for tv in validation_videos if tv not in excepetion_videos]
test_videos = [ tv for tv in test_videos if tv not in excepetion_videos]
print(len(train_videos),train_videos)
print(len(validation_videos), validation_videos)
print(len(test_videos),test_videos)
# Out:
# 251 ['70_1', '70_2', '70_3', '70_4', '70_5', '9_1', '9_2', '9_3', '9_4', '9_5', '44_1', '44_2', '44_3', '44_4', '44_5', '94_1', '94_2', '94_3', '94_4', '94_5', '37_1', '37_2', '37_3', '37_4', '37_5', '77_1', '77_2', '77_3', '77_4', '77_5', '56_1', '56_2', '56_3', '56_4', '56_5', '13_1', '13_2', '13_3', '13_4', '13_5', '34_2', '34_3', '34_4', '34_5', '93_1', '93_2', '93_3', '93_4', '93_5', '1_1', '1_2', '1_3', '1_4', '1_5', '33_1', '33_2', '33_3', '33_4', '33_5', '53_1', '53_2', '53_3', '53_4', '53_5', '63_1', '63_2', '63_3', '63_4', '63_5', '65_1', '65_2', '65_3', '65_4', '65_5', '46_1', '46_2', '46_3', '46_4', '46_5', '67_1', '67_2', '67_3', '67_4', '67_5', '27_1', '27_2', '27_3', '27_4', '27_5', '75_1', '75_2', '75_3', '75_4', '75_5', '82_1', '82_2', '82_3', '82_4', '82_5', '59_1', '59_2', '59_3', '59_4', '59_5', '66_1', '66_2', '66_3', '66_4', '66_5', '22_1', '22_2', '22_3', '22_4', '22_5', '3_1', '3_2', '3_3', '3_4', '3_5', '90_1', '90_2', '90_3', '90_4', '90_5', '96_1', '96_2', 
# ...

# %% [markdown]
# # Train

# %%
# ##Train and test splitting functions (subject dependent)
# import random
# import numpy as np

# fp1 = [1,5,9,14,15,24,25,42,48,54]
# fp2 = [4,13,16,18,21,23,27,28,30,32,35,36,39,43,44,47,49,50,51,52,53,58,60,63,64,65]#,69]
# fp3 = [3,8,10,12,17,20,29,33,34,38,55,62]
# fp4 = [6,7,22,46,66]
# fp5 = [2,19,26,37,40,41,45,56,59,61]
# fp6 = [11,31,57]

# fpL = fp1+fp2
# fpM = fp3+fp4
# fpD = fp5+fp6

# random.shuffle(fpL)

# random.shuffle(fpM)
# random.shuffle(fpD)


# exceptions = ['4_1','34_1']



# def remove_exceptions(l,ex):
#     l_dash = []
#     for i in l:
#         if i not in ex:
#             l_dash.append(i)
#     return l_dash

# def train_test_split_subDep(fp1,fp2,fp3,fp4,fp5,fp6,split,exceptions):

#     #split is a three element list of ratios of L, M, D eg. [0.3,0.3,0.4]
#     fpL = fp1+fp2
#     fpM = fp3+fp4
#     fpD = fp5+fp6

#     random.shuffle(fpL)
#     random.shuffle(fpM)
#     random.shuffle(fpD)

#     siz = min([len(fpL),len(fpM),len(fpD)])

#     L_use = fpL[0:siz]
#     M_use = fpM[0:siz]
#     D_use = fpD[0:siz]

#     Lno = int(np.floor(siz*split[0]))
#     Mno = int(np.floor(siz*split[1]))
#     Dno = int(np.floor(siz*split[2]))

#     train = [1,3,4]
#     test = [2,5]

#     train_split = []
#     for i in L_use[0:Lno]:
#         for j in train:
#             train_split.append(str(i)+'_'+str(j))

#     for i in M_use[0:Mno]:
#         for j in train:
#             train_split.append(str(i)+'_'+str(j))

#     for i in D_use[0:Dno]:
#         for j in train:
#             train_split.append(str(i)+'_'+str(j))
    
#     test_split_L = []
#     for i in L_use:
#         for j in test:
#             test_split_L.append(str(i)+'_'+str(j))

#     test_split_M = []
#     for i in M_use:
#         for j in test:
#             test_split_M.append(str(i)+'_'+str(j))

#     test_split_D = []
#     for i in D_use:
#         for j in test:
#             test_split_D.append(str(i)+'_'+str(j))

#     train_split = remove_exceptions(train_split,exceptions)
#     test_split_L = remove_exceptions(test_split_L,exceptions)
#     test_split_M = remove_exceptions(test_split_M,exceptions)
#     test_split_D = remove_exceptions(test_split_D,exceptions)

#     val_split = test_split_L+test_split_M+test_split_D
    


#     return train_split, test_split_L, test_split_M, test_split_D, val_split

# train_split, test_split_L, test_split_M, test_split_D, val_split = train_test_split_subDep(fp1,fp2,fp3,fp4,fp5,fp6,[0.75,0,0.25],exceptions)

# print(train_split)
# print(test_split_L)
# print(test_split_M)
# print(test_split_D)

# %%
params = {
  'lr': 0.00001,
  'min_lr_ratio': 0.01,
  'weight_decay': 0.01,
  'num_samples': 160,
  'seq_length': 128,
  'batch_size': 6,
  'img_shape': (128, 128),
  'num_epochs': 60,
  'snr_epoch': 10,
  'check_point_dir': 'extension_checkpoints/diplav/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21/physnet_lr00001/', # To diplav: I usually store it in extension_checkpoints. you can give it a name after /.
  # 'extension_checkpoints/physnet_lr00005_biofacenet_recon_ref_image_ppb_bidmc_08_12_120videos_background_downsampled', # bupt_balanced_480_09_11_no_mask_11_13_albedo_rgbweight_v1', # 'finetune_bupt_balanced_480_11_09_no_mask_10_12_prn_v1_prn00004',
  'pretrained_weights': None #'checkpoints/physnet_bupt_balanced_480_11_09_no_mask_10_12_dark_v3/model_best.pt' # 'checkpoints/bupt_balanced_480_11_09_no_mask_10_12_prn_00004/model_best.pt'
}

# create output dir
if params['check_point_dir']:
  try:
    os.makedirs(f"checkpoints/{params['check_point_dir']}")
    print("Output directory is created")
  except FileExistsError:
    reply = input('Override existing weights? [y/n]')
    if reply == 'n':
      print('Add another outout path then!')
      sys.exit()
# Out:
# Output directory is created

# %%
root_dir = ['/content/gdrive/.shortcut-targets-by-id/1-up69TInc1tooCgwD7Ad1oOGMayBzkYe/R_PPG_estimation/zw_VITAL2_h5cropped_downsampled', '/content/bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21'] 
#'/content/synthetic_dataset/biofacenet_recon_ref_image_ppb_bidmc_08_12_120videos_background_downsampled']
# bupt_balanced_480_09_11_no_mask_11_13_albedo_rgbweight

# %%
train_session_nums = train_videos
val_session_nums = validation_videos

train_all = [] 
val_all = []
train_session_names = []
val_session_names = []

for cur_session_num in train_session_nums:
  sn = cur_session_num.split('_')[0]
  cur_session_name = 'subject'+ sn + '/' + cur_session_num
  train_session_names.append(cur_session_name)
print(train_session_names)
train_all.append(train_session_names)

for cur_session_num in val_session_nums:
  sn = cur_session_num.split('_')[0]
  cur_session_name = 'subject'+ sn + '/' + cur_session_num
  val_session_names.append(cur_session_name)
print(val_session_names)
val_all.append(val_session_names)

len_synthetic = len(os.listdir(root_dir[1]))#[238:358])
print(len_synthetic)
session_nums = np.random.permutation(np.arange(len_synthetic))

train_session_syn_nums = []
val_session_syn_nums = []
train_session_syn_nums.append(session_nums[:np.int(len_synthetic*0.8)])
val_session_syn_nums.append(session_nums[np.int(len_synthetic*0.8):])

train_all.append(list(train_session_syn_nums[0]))
val_all.append(list(val_session_syn_nums[0]))
# Out:
# ['subject70/70_1', 'subject70/70_2', 'subject70/70_3', 'subject70/70_4', 'subject70/70_5', 'subject9/9_1', 'subject9/9_2', 'subject9/9_3', 'subject9/9_4', 'subject9/9_5', 'subject44/44_1', 'subject44/44_2', 'subject44/44_3', 'subject44/44_4', 'subject44/44_5', 'subject94/94_1', 'subject94/94_2', 'subject94/94_3', 'subject94/94_4', 'subject94/94_5', 'subject37/37_1', 'subject37/37_2', 'subject37/37_3', 'subject37/37_4', 'subject37/37_5', 'subject77/77_1', 'subject77/77_2', 'subject77/77_3', 'subject77/77_4', 'subject77/77_5', 'subject56/56_1', 'subject56/56_2', 'subject56/56_3', 'subject56/56_4', 'subject56/56_5', 'subject13/13_1', 'subject13/13_2', 'subject13/13_3', 'subject13/13_4', 'subject13/13_5', 'subject34/34_2', 'subject34/34_3', 'subject34/34_4', 'subject34/34_5', 'subject93/93_1', 'subject93/93_2', 'subject93/93_3', 'subject93/93_4', 'subject93/93_5', 'subject1/1_1', 'subject1/1_2', 'subject1/1_3', 'subject1/1_4', 'subject1/1_5', 'subject33/33_1', 'subject33/33_2', 'subject3
# ...

# %%
# !ls /content/
# Out:
# bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21	   gdrive
# bupt_balanced_480_09_11_no_mask_fmel_multiplication_09_11_3_21.7z  sample_data

# %%
# root_dir = '/content/VITAL2_h5cropped_pc_92'

# hr_path = '/content/gdrive/My Drive/R_PPG_estimation/trial_videos_VITAL2'

train_set = DatasetUBFC(
    root_dir=root_dir, 
    session_names=train_all, 
    num_samples=params['num_samples'],
    seq_length=params['seq_length'], 
    resize_shape=params['img_shape']
    )
# Out:
# 2 [['subject70/70_1', 'subject70/70_2', 'subject70/70_3', 'subject70/70_4', 'subject70/70_5', 'subject9/9_1', 'subject9/9_2', 'subject9/9_3', 'subject9/9_4', 'subject9/9_5', 'subject44/44_1', 'subject44/44_2', 'subject44/44_3', 'subject44/44_4', 'subject44/44_5', 'subject94/94_1', 'subject94/94_2', 'subject94/94_3', 'subject94/94_4', 'subject94/94_5', 'subject37/37_1', 'subject37/37_2', 'subject37/37_3', 'subject37/37_4', 'subject37/37_5', 'subject77/77_1', 'subject77/77_2', 'subject77/77_3', 'subject77/77_4', 'subject77/77_5', 'subject56/56_1', 'subject56/56_2', 'subject56/56_3', 'subject56/56_4', 'subject56/56_5', 'subject13/13_1', 'subject13/13_2', 'subject13/13_3', 'subject13/13_4', 'subject13/13_5', 'subject34/34_2', 'subject34/34_3', 'subject34/34_4', 'subject34/34_5', 'subject93/93_1', 'subject93/93_2', 'subject93/93_3', 'subject93/93_4', 'subject93/93_5', 'subject1/1_1', 'subject1/1_2', 'subject1/1_3', 'subject1/1_4', 'subject1/1_5', 'subject33/33_1', 'subject33/33_2', 'subje
# ...

# %%
val_set = DatasetUBFC(
    root_dir=root_dir, 
    session_names=val_all, 
    num_samples=params['num_samples'],
    seq_length=params['seq_length'], 
    resize_shape=params['img_shape'],
    val = True
    )
# Out:
# 2 [['subject62/62_1', 'subject62/62_2', 'subject62/62_3', 'subject62/62_4', 'subject62/62_5', 'subject101/101_1', 'subject101/101_2', 'subject101/101_3', 'subject101/101_4', 'subject101/101_5', 'subject14/14_1', 'subject14/14_2', 'subject14/14_3', 'subject14/14_4', 'subject14/14_5', 'subject12/12_1', 'subject12/12_2', 'subject12/12_3', 'subject12/12_4', 'subject12/12_5', 'subject80/80_1', 'subject80/80_2', 'subject80/80_3', 'subject80/80_4', 'subject80/80_5', 'subject72/72_1', 'subject72/72_2', 'subject72/72_3', 'subject72/72_4', 'subject72/72_5', 'subject25/25_1', 'subject25/25_2', 'subject25/25_3', 'subject25/25_4', 'subject25/25_5', 'subject85/85_1', 'subject85/85_2', 'subject85/85_3', 'subject85/85_4', 'subject85/85_5', 'subject18/18_1', 'subject18/18_2', 'subject18/18_3', 'subject18/18_4', 'subject18/18_5', 'subject79/79_1', 'subject79/79_2', 'subject79/79_3', 'subject79/79_4', 'subject79/79_5'], [417, 425, 76, 474, 152, 432, 94, 83, 438, 404, 281, 52, 277, 233, 60, 311, 237, 41
# ...

# %%
ppg_train_loader = DataLoader(
    train_set,
    batch_size=params['batch_size'],
    shuffle=True,
    num_workers=0,
    pin_memory=True
    )


ppg_val_loader = DataLoader(
    val_set,
    batch_size=params['batch_size'],
    shuffle=False,
    num_workers=0,
    pin_memory=True
    )

dataloaders = {'train': ppg_train_loader, 'val': ppg_val_loader}
print('\nDataLoaders succesfully constructed!')
# Out:
# DataLoaders succesfully constructed!

# %%
# model = RPPGNet(params['seq_length'])
model = PhysNet(params['seq_length'])
# model = RPPGNetResnet(params['seq_length'])


# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

# If there are pretrained weights, initialize model
if params['pretrained_weights']:
  model.load_state_dict(tr.load(params['pretrained_weights']))
  print('\nPre-trained weights are loaded!')

# Copy model to working device
model = model.to(device)

# criterion
criterion = Neg_Pearson()   # rPPG singal 
# criterion = Neg_Pearson_focal()   # rPPG singal 
# criterion = nn.MSELoss()   # rPPG singal 

print('====loss====', criterion)
print('====lr====',  params['lr'])
print('====weight_decay====',  params['weight_decay'])

optimizer = optim.AdamW(
    model.parameters(), 
    lr=params['lr'], 
    betas=(0.5, 0.999), 
    weight_decay=params['weight_decay']
    )

scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=params['num_epochs'], 
    eta_min=params['min_lr_ratio'] * params['lr'], verbose=True
    )

train_model(
    model, 
    dataloaders, 
    criterion, 
    optimizer, 
    scheduler, 
    params
    )

print('\nTraining is finished without flaw!')
# Out:
# Device: cuda
# ====loss==== Neg_Pearson()
# ====lr==== 1e-05
# ====weight_decay==== 0.01
# Adjusting learning rate of group 0 to 1.0000e-05.
# Epoch 0/60
# ----------
# train Loss: 0.9999
# val Loss: 0.9984
# saving in epoch 0
# new min loss: 0.9984058737754822
# Adjusting learning rate of group 0 to 9.9932e-06.
#
#
# Epoch 1/60
# ----------
# train Loss: 0.9996
# val Loss: 1.0003
# Adjusting learning rate of group 0 to 9.9729e-06.
#
#
# Epoch 2/60
# ----------
# train Loss: 0.9982
# val Loss: 0.9995
# Adjusting learning rate of group 0 to 9.9391e-06.
#
#
# Epoch 3/60
# ----------
# train Loss: 1.0006
# val Loss: 0.9997
# Adjusting learning rate of group 0 to 9.8918e-06.
#
#
# Epoch 4/60
# ----------
# train Loss: 0.9948
# val Loss: 0.9965
# saving in epoch 4
# new min loss: 0.9965138722349096
# Adjusting learning rate of group 0 to 9.8313e-06.
#
#
# Epoch 5/60
# ----------
# train Loss: 0.9954
# val Loss: 0.9943
# saving in epoch 5
# new min loss: 0.9942716492546929
# ...

# %%
print(train_split)
print(test_split_L)
print(test_split_M)
print(test_split_D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-8b687070f1de> in <module>()
# ----> 1 print(train_split)
#       2 print(test_split_L)
#       3 print(test_split_M)
#       4 print(test_split_D)
#
# NameError: name 'train_split' is not defined

# %% [markdown]
# # Test

# %%
# params = {
#   'lr': 0.0002,
#   'min_lr_ratio': 0.01,
#   'weight_decay': 0.01,
#   'num_samples': 160,
#   'seq_length': 256,
#   'batch_size': 8,
#   'img_shape': (80, 80),
#   'num_epochs': 60,
#   'snr_epoch': 10,
#   'check_point_dir': 'pc_split_0.75L0.25D_9_4',
#   'pretrained_weights': None
# }


# model = RPPGNet(params['seq_length'])

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# print('Device:', device)

# model = model.to(device)

# %%
from scipy.signal import butter

def butter_bandpass(lowcut, highcut, fs, order=6):
    from scipy.signal import butter
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=6):
    from scipy.signal import lfilter
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def heart_beat(signal, label):
    pred_signal = butter_bandpass_filter(signal, 0.7, 2.5, sample_rate)
    f, Pxx = scipy.signal.periodogram(pred_signal, fs=sample_rate)
    heart_rate = f[np.argmax(Pxx)] * 60
    # plt.figure(figsize=(20, 10))
    # plt.plot((f * 60)[:180], Pxx[:180], label=label)
    return heart_rate

import numpy as np
import plotly.graph_objects as go
#from bvp import BVPsignal

def getErrors(bpmES, bpmGT, timesES=None, timesGT=None):
    RMSE = RMSEerror(bpmES, bpmGT, timesES, timesGT)
    MAE = MAEerror(bpmES, bpmGT, timesES, timesGT)
    MAX = MAXError(bpmES, bpmGT, timesES, timesGT)
    PCC = PearsonCorr(bpmES, bpmGT, timesES, timesGT)
    return RMSE, MAE, MAX, PCC

def RMSEerror(bpmES, bpmGT, timesES=None, timesGT=None):
    """ RMSE: """

    diff = bpm_diff(bpmES, bpmGT, timesES, timesGT)
    n,m = diff.shape  # n = num channels, m = bpm length
    df = np.zeros(n)
    for j in range(m):
        for c in range(n):
            df[c] += np.power(diff[c,j],2)

    # -- final RMSE
    RMSE = np.sqrt(df/m)
    return RMSE

def MAEerror(bpmES, bpmGT, timesES=None, timesGT=None):
    """ MAE: """

    diff = bpm_diff(bpmES, bpmGT, timesES, timesGT)
    n,m = diff.shape  # n = num channels, m = bpm length
    df = np.sum(np.abs(diff),axis=1)

    # -- final MAE
    MAE = df/m
    return MAE

def MAXError(bpmES, bpmGT, timesES=None, timesGT=None):
    """ MAE: """

    diff = bpm_diff(bpmES, bpmGT, timesES, timesGT)
    n,m = diff.shape  # n = num channels, m = bpm length
    df = np.max(np.abs(diff),axis=1)

    # -- final MAE
    MAX = df
    return MAX

def PearsonCorr(bpmES, bpmGT, timesES=None, timesGT=None):
    from scipy import stats

    diff = bpm_diff(bpmES, bpmGT, timesES, timesGT)
    n,m = diff.shape  # n = num channels, m = bpm length
    CC = np.zeros(n)
    for c in range(n):
        # -- corr
        r,p = stats.pearsonr(diff[c,:]+bpmES[c,:],bpmES[c,:])
        CC[c] = r
    return CC

def printErrors(RMSE, MAE, MAX, PCC):
    print("\n    * Errors: RMSE = %.2f, MAE = %.2f, MAX = %.2f, PCC = %.2f" %(RMSE,MAE,MAX,PCC))

def displayErrors(bpmES, bpmGT, timesES=None, timesGT=None):
    
    n,m = bpmES.shape  # n = num channels, m = bpm length

    if (timesES is None) or (timesGT is None):
        timesES = np.arange(m)
        timesGT = timesES
        
    diff = bpm_diff(bpmES, bpmGT, timesES, timesGT)
    n,m = diff.shape  # n = num channels, m = bpm length
    df = np.abs(diff)
    dfMean = np.around(np.mean(df,axis=1),1)

    # -- plot errors
    fig = go.Figure()
    name = 'Ch 1 (µ = ' + str(dfMean[0])+ ' )'
    fig.add_trace(go.Scatter(x=timesES, y=df[0,:], name=name, mode='lines+markers'))
    if n > 1:
        name = 'Ch 2 (µ = ' + str(dfMean[1])+ ' )'
        fig.add_trace(go.Scatter(x=timesES, y=df[1,:], name=name, mode='lines+markers'))
        name = 'Ch 3 (µ = ' + str(dfMean[2])+ ' )'
        fig.add_trace(go.Scatter(x=timesES, y=df[2,:], name=name, mode='lines+markers'))
    fig.update_layout(xaxis_title='Times (sec)', yaxis_title='MAE', showlegend=True)
    fig.show()

    # -- plot bpm Gt and ES 
    fig = go.Figure()
    GTmean = np.around(np.mean(bpmGT),1)
    name = 'GT (µ = ' + str(GTmean)+ ' )'
    fig.add_trace(go.Scatter(x=timesGT, y=bpmGT, name=name, mode='lines+markers'))
    ESmean = np.around(np.mean(bpmES[0,:]),1)
    name = 'ES1 (µ = ' + str(ESmean)+ ' )'
    fig.add_trace(go.Scatter(x=timesES, y=bpmES[0,:], name=name, mode='lines+markers'))
    if n > 1:
        ESmean = np.around(np.mean(bpmES[1,:]),1)
        name = 'ES2 (µ = ' + str(ESmean)+ ' )'
        fig.add_trace(go.Scatter(x=timesES, y=bpmES[1,:], name=name, mode='lines+markers'))
        ESmean = np.around(np.mean(bpmES[2,:]),1)
        name = 'E3 (µ = ' + str(ESmean)+ ' )'
        fig.add_trace(go.Scatter(x=timesES, y=bpmES[2,:], name=name, mode='lines+markers'))

    fig.update_layout(xaxis_title='Times (sec)', yaxis_title='BPM', showlegend=True)
    fig.show()


def bpm_diff(bpmES, bpmGT, timesES=None, timesGT=None):
    n,m = bpmES.shape  # n = num channels, m = bpm length

    if (timesES is None) or (timesGT is None):
        timesES = np.arange(m)
        timesGT = timesES
            
    diff = np.zeros((n,m))
    for j in range(m):
        t = timesES[j]
        i = np.argmin(np.abs(t-timesGT))
        for c in range(n):
            diff[c,j] = bpmGT[i]-bpmES[c,j]
    return diff

import scipy
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import spdiags

def detrend(signal, Lambda):
    """detrend(signal, Lambda) -> filtered_signal
    This function applies a detrending filter.
    This code is based on the following article "An advanced detrending method with application
    to HRV analysis". Tarvainen et al., IEEE Trans on Biomedical Engineering, 2002.
    *Parameters*
      ``signal`` (1d numpy array):
        The signal where you want to remove the trend.
      ``Lambda`` (int):
        The smoothing parameter.
    *Returns*
      ``filtered_signal`` (1d numpy array):
        The detrended signal.
    """
    signal_length = signal.shape[0]

    # observation matrix
    H = np.identity(signal_length)

    # second-order difference matrix

    ones = np.ones(signal_length)
    minus_twos = -2 * np.ones(signal_length)
    diags_data = np.array([ones, minus_twos, ones])
    diags_index = np.array([0, 1, 2])
    D = spdiags(diags_data, diags_index, (signal_length - 2), signal_length).toarray()
    filtered_signal = np.dot((H - np.linalg.inv(H + (Lambda ** 2) * np.dot(D.T, D))), signal)
    return filtered_signal

def prpsd(BVP, FS, LL_PR, UL_PR, BUTTER_ORDER=6, DETREND=False, PlotTF=False):
    # %PRPSD Estimates a pulse rate from a BVP signal
    # % Inputs:
    # %       BVP                     = A BVP timeseries.
    # %       FS                      = The sample rate of the BVP time series (Hz/fps).
    # %       LL_PR                    = The lower limit for pulse rate (bpm).
    # %       UL_PR                    = The upper limit for pulse rate (bpm).
    # %       PlotTF                  = Boolean to turn plotting results on or off.
    # %
    # %   Outputs:
    # %       PR                      = The estimated PR in BPM.
    # %
    # % Daniel McDuff, Ethan Blackford, January 2019
    # % Copyright (c)
    # % Licensed under the MIT License and the RAIL AI License.

    Nyquist = FS/2;
    FResBPM = 0.5;  # resolution (bpm) of bins in power spectrum used to determine PR and SNR
    
    N = (60*2*Nyquist)/FResBPM;

    # Detrending + 6th order butterworth + periodogram
    if DETREND:
      BVP = detrend(np.cumsum(BVP), 100)

    if BUTTER_ORDER and BUTTER_ORDER == 1:
      [b, a] = butter(1, [0.75 / FS * 2, 2.5 / FS * 2], btype='bandpass') # 2.5 -> 1.7
    else:
      [b, a] = butter(6, [0.75 / FS * 2, 2.5 / FS * 2], btype='bandpass') # 2.5 -> 1.7

    BVP = scipy.signal.filtfilt(b, a, np.double(BVP))
    
    if DETREND:
      F, Pxx = signal.periodogram(x=BVP,  nfft=N, fs=FS, detrend=False);  
    else:
      F, Pxx = signal.periodogram(x=BVP, window=np.hamming(len(BVP)), nfft=N, fs=FS);
   
    FMask = (F >= (LL_PR/60)) & (F <= (UL_PR/60));
    
    # Calculate predicted HR:
    FRange = F * FMask;
    PRange = Pxx * FMask;
    MaxInd = np.argmax(PRange);
    PR_F = FRange[MaxInd];
    PR = PR_F*60;
    # fmask_pred = np.argwhere((F >= 0.75) & (F <= 2.5))
    # pred_window = np.take(F, fmask_pred)
    # PR = np.take(pred_window, np.argmax(np.take(Pxx, fmask_pred), 0))[0] * 60

    # Optionally Plot the PSD and peak frequency
    if PlotTF:
        # Plot PSD (in dB) and peak frequency
        plt.figure();
        plt.plot(F, 10 * np.log10(Pxx))
        plt.plot(PR_F, 10 * np.log10(PRange[MaxInd]),'ro')
        # text(PR_F,pow2db(PRange(MaxInd)),['   ' num2str(PR_F,'%3.2f') ' Hz; ' num2str(PR,'%4.1f'),' bpm'])
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Power (dB)')
        plt.xlim([0, 4.5])
        plt.title('Power Spectrum and Peak Frequency')
            
    return PR

# %%
test_split_L_t = ['13_2', '13_5', '42_2', '42_5', '52_2', '52_5', '58_2', '58_5', '15_2', '15_5', '39_2', '39_5', '5_2', '5_5', '65_2', '65_5', '1_2', '1_5', '35_2', '35_5', '64_2', '64_5', '51_2', '51_5', '49_2', '49_5']
test_split_M_t = ['17_2', '17_5', '7_2', '7_5', '20_2', '20_5', '22_2', '22_5', '3_2', '3_5', '6_2', '6_5', '38_2', '38_5', '10_2', '10_5', '62_2', '62_5', '33_2', '33_5', '12_2', '12_5', '8_2', '8_5', '34_2', '34_5']
test_split_D_t = ['2_2', '2_5', '37_2', '37_5', '19_2', '19_5', '57_2', '57_5', '59_2', '59_5', '31_2', '31_5', '40_2', '40_5', '26_2', '26_5', '56_2', '56_5', '61_2', '61_5', '41_2', '41_5', '45_2', '45_5', '11_2', '11_5']

# %%
resize_shape = (80, 80)
sequence_length = 256
check_point_dir = 'pc_split_0.5L0.5D_9_4'
pretrained_weight_path = os.path.join('checkpoints/', check_point_dir + '/model_best.pt')
# pretrained_weight_path = os.path.join('checkpoints/', check_point_dir + '/model0_best.pt')
#pretrained_weight_path = '/content/gdrive/My Drive/train_generation_314/deepphys_weight/3dcnn_ubfc_model0_ep29.pt'
#pretrained_weight_path = '/content/gdrive/My Drive/VGG1200-Races-master/model_checkpoints_aligned/video2video_train_both_3dcnn_and_g_3dcnn_4_12_zw.pt'
# model = RPPGNet(sequence_length).cuda()

#model.load_state_dict(torch.load(pretrained_weight_path)['model_state_dict'])
model.load_state_dict(torch.load(pretrained_weight_path))
model.eval()
# detector = MTCNN()

session_nums = test_split_D_t  #[14, 15, 22, 30, 34, 37, 43, 44, 46, 48]
# root_dir = '/content/VITAL2_h5cropped_pc'
root_dir = '/content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc'

video_samples = []
session_names = []

for cur_session_num in session_nums:
  sn = cur_session_num.split('_')[0]
  cur_session_name = 'subject'+ sn + '/' + cur_session_num
  session_names.append(cur_session_name)

for cur_session in session_names:
  video_sample = {
      'video_path': os.path.join(root_dir, cur_session + '.h5'),
      'gt_path': '/content/gdrive/My Drive/R_PPG_estimation/trial_videos_VITAL2/' + cur_session +'/hr.csv'
  }
  video_samples.append(video_sample)

for cur_video_sample in video_samples:
  cur_video_path = cur_video_sample['video_path']
  cur_est_ppgs = None

  # Set video reader
  db = h5py.File(cur_video_path, 'r')

  frames = db['dataset_1']
  target = db['ppg']
  print('Video:', cur_video_path)

  for cur_frame_num in range(frames.shape[0]):
  
    cur_frame = frames[cur_frame_num, :, :, :]
    #img_show(cur_frame_cropped)
    cur_frame_cropped = cv2.resize(cur_frame, resize_shape, interpolation=cv2.INTER_LINEAR)
    # Preprocess
    cur_frame_cropped = torch.from_numpy(cur_frame_cropped).permute(2, 0, 1).float()
    
    cur_frame_cropped = cur_frame_cropped / 127.5 - 1
    #cur_frame_cropped = tr.sub(cur_frame_cropped, tr.mean(cur_frame_cropped, (1, 2)).view(3, 1, 1))  # Color channel centralization
    #cur_frame_cropped = cur_frame_cropped / 255
    cur_frame_cropped = cur_frame_cropped.unsqueeze(0).cuda() # Add the T dim
    # tensor_show(cur_frame_cropped)

    # Concat
    if cur_frame_num % sequence_length == 0:
      cur_cat_frames = cur_frame_cropped
    else:
      cur_cat_frames = torch.cat((cur_cat_frames, cur_frame_cropped), 0)

    # Test the performance
    if cur_cat_frames.shape[0] == sequence_length:
      
      # DL
      with torch.no_grad():
        cur_cat_frames = cur_cat_frames.unsqueeze(0) # Add the B dim
        cur_cat_frames = torch.transpose(cur_cat_frames, 1, 2)
        cur_est_ppg = model(cur_cat_frames)
        cur_est_ppg = cur_est_ppg.squeeze().cpu().numpy()

      # First seq
      if cur_est_ppgs is None: 
        cur_est_ppgs = cur_est_ppg
      else:
        cur_est_ppgs = np.concatenate((cur_est_ppgs, cur_est_ppg), -1)
  
  # Save
  cur_video_sample['est_ppgs'] = cur_est_ppgs
  cur_video_sample['gt_ppgs'] = target
  print('Sample finished!\n')
print('All finished!')
# Out:
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject2/2_2.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject2/2_5.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject37/37_2.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject37/37_5.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject19/19_2.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject19/19_5.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject57/57_2.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject57/57_5.h5
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject59/59_2.h5
# Sample finished!
#
# ...

# %%
#Estimate using hr

hr_window_size = 900
stride = 30
mae_list = []
for index, cur_video_sample in enumerate(video_samples):
  cur_video_path = cur_video_sample['video_path']
  print('Video:', cur_video_path)
  cur_est_ppgs = cur_video_sample['est_ppgs']

  # Load GT
  hr_file = pd.read_csv(cur_video_sample['gt_path'], header=None)
  cur_gt_hr = hr_file[0].values
 
  video_fps = 30
  #gtHR = cur_hr_signal

  print(cur_gt_hr.shape)
  cur_gt_hr = cur_gt_hr[:len(cur_est_ppgs)]
  print(cur_est_ppgs.shape)
  
  #print(cur_gt_hr)
  cur_est_ppgs = (cur_est_ppgs - np.mean(cur_est_ppgs)) / np.std(cur_est_ppgs)
  #cur_est_ppgs = detrend(np.cumsum(cur_est_ppgs), 100) # could do this in prpsd func
  #BVP = detrend(np.cumsum(BVP), 100)
  #cur_est_ppgs = scipy.signal.filtfilt(b, a, np.double(cur_est_ppgs))
  # Get est HR for each window
  hr_est_temp = []
  hr_gt_temp = []
  for start in range(0, len(cur_est_ppgs) - hr_window_size, stride):
    ppg_est_window = cur_est_ppgs[start:start + hr_window_size]
   
    # Normalize PPG
    ppg_est_window = (ppg_est_window - np.mean(ppg_est_window)) / np.std(ppg_est_window)
    hr_est_temp.append(prpsd(ppg_est_window, 30, 45, 150, BUTTER_ORDER=6, DETREND=False))
    hr_gt_temp.append(np.mean(cur_gt_hr[start:start+hr_window_size]))
  print(hr_est_temp)
  print(hr_gt_temp)

  hr_est_windowed = np.array([hr_est_temp])
  hr_gt_windowed = np.array(hr_gt_temp)

  # Errors
  RMSE, MAE, MAX, PCC = getErrors(hr_est_windowed, hr_gt_windowed)
  printErrors(RMSE, MAE, MAX, PCC)
 
  mae_list.append(MAE)
  print('Sample finished!\n')
print('MAE List:', np.array(mae_list))
print('Mean MAE:', np.mean(np.array(mae_list)))
# Out:
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject2/2_2.h5
# (1790,)
# (1536,)
# [70.0, 70.0, 69.5, 69.5, 69.5, 69.5, 69.0, 69.0, 69.0, 69.0, 69.0, 69.5, 69.5, 69.5, 70.0, 70.0, 70.0, 70.5, 70.5, 70.5, 70.5, 70.5]
# [74.1211111111111, 73.88777777777777, 73.65444444444445, 73.42111111111112, 73.18777777777778, 72.95444444444445, 72.75055555555555, 72.61166666666666, 72.45722222222223, 72.32388888888889, 72.215, 72.115, 72.04833333333333, 71.98166666666667, 71.915, 71.86611111111111, 71.8561111111111, 71.88388888888889, 71.91722222222222, 71.95055555555555, 71.95055555555555, 71.95055555555555]
#
#     * Errors: RMSE = 2.95, MAE = 2.77, MAX = 4.15, PCC = -0.26
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject2/2_5.h5
# (1790,)
# (1536,)
# [70.0, 70.0, 70.5, 70.5, 70.5, 70.5, 70.5, 70.5, 71.0, 71.0, 71.0, 71.0, 71.5, 71.5, 71.5, 71.5, 71.5, 72.0, 72.0, 72.0, 72.0, 72.0]
# ...

# %%
#Estimate using waveforms

hr_window_size = 900
stride = 30
mae_list = []
for index, cur_video_sample in enumerate(video_samples):
  cur_video_path = cur_video_sample['video_path']
  print('Video:', cur_video_path)
  cur_est_ppgs = cur_video_sample['est_ppgs']

  # Load GT
  cur_gt_ppgs = cur_video_sample['gt_ppgs']
 
  video_fps = 30
  #gtHR = cur_hr_signal

  print(cur_est_ppgs.shape)
  
  #print(cur_gt_hr)
  cur_est_ppgs = (cur_est_ppgs - np.mean(cur_est_ppgs)) / np.std(cur_est_ppgs)

  cur_gt_ppgs = (cur_gt_ppgs - np.mean(cur_gt_ppgs)) / np.std(cur_gt_ppgs)
  #cur_est_ppgs = detrend(np.cumsum(cur_est_ppgs), 100) # could do this in prpsd func
  #BVP = detrend(np.cumsum(BVP), 100)
  #cur_est_ppgs = scipy.signal.filtfilt(b, a, np.double(cur_est_ppgs))
  # Get est HR for each window
  hr_est_temp = []
  hr_gt_temp = []
  for start in range(0, len(cur_est_ppgs) - hr_window_size, stride):
    ppg_est_window = cur_est_ppgs[start:start + hr_window_size]

    ppg_gt_window = cur_gt_ppgs[start:start + hr_window_size]
   
    # Normalize PPG
    ppg_est_window = (ppg_est_window - np.mean(ppg_est_window)) / np.std(ppg_est_window)
    ppg_gt_window = (ppg_gt_window - np.mean(ppg_gt_window)) / np.std(ppg_gt_window)
    hr_est_temp.append(prpsd(ppg_est_window, 30, 45, 150, BUTTER_ORDER=6, DETREND=False))
    hr_gt_temp.append(prpsd(ppg_gt_window, 30, 45, 150, BUTTER_ORDER=6, DETREND=False))
  print(hr_est_temp)
  print(hr_gt_temp)

  hr_est_windowed = np.array([hr_est_temp])
  hr_gt_windowed = np.array(hr_gt_temp)

  # Errors
  RMSE, MAE, MAX, PCC = getErrors(hr_est_windowed, hr_gt_windowed)
  printErrors(RMSE, MAE, MAX, PCC)
 
  mae_list.append(MAE)
  print('Sample finished!\n')
print('MAE List:', np.array(mae_list))
print('Mean MAE:', np.mean(np.array(mae_list)))
# Out:
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject2/2_2.h5
# (1536,)
# [70.0, 70.0, 69.5, 69.5, 69.5, 69.5, 69.0, 69.0, 69.0, 69.0, 69.0, 69.5, 69.5, 69.5, 70.0, 70.0, 70.0, 70.5, 70.5, 70.5, 70.5, 70.5]
# [70.0, 70.0, 69.5, 69.5, 69.5, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 69.5, 69.5, 69.5, 70.0, 70.0, 70.5, 70.5, 70.5, 70.5, 70.5, 70.5]
#
#     * Errors: RMSE = 0.15, MAE = 0.05, MAX = 0.50, PCC = 0.97
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject2/2_5.h5
# (1536,)
# [70.0, 70.0, 70.5, 70.5, 70.5, 70.5, 70.5, 70.5, 71.0, 71.0, 71.0, 71.0, 71.5, 71.5, 71.5, 71.5, 71.5, 72.0, 72.0, 72.0, 72.0, 72.0]
# [70.0, 70.5, 70.5, 70.5, 70.5, 70.5, 71.0, 71.0, 71.0, 71.0, 71.0, 71.5, 71.5, 71.5, 71.5, 71.5, 71.5, 71.5, 72.0, 72.0, 72.0, 72.0]
#
#     * Errors: RMSE = 0.24, MAE = 0.11, MAX = 0.50, PCC = 0.94
# Sample finished!
#
# Video: /content/gdrive/My Drive/R_PPG_estimation/VITAL2_h5cropped_pc/subject37/37_2.h5
# ...

# %%
pwd
# Out:
# '/content/gdrive/.shortcut-targets-by-id/1ija91QruitXYileHYYttNQceqMiIyDpb/Colorless Camera'
